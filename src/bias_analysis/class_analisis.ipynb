# %%
import json

# %%
file_path = r'C:\Users\wang\Desktop\0000012_semantic.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'annotations': [{'segmentation': {'size': [256, 256],
#     'counts': 'iV5112i70WH4e7J\\H;^7EcH>Z7CdH?[7BeH?Y7@gHc0W7]OjHb0V74000000O1OXOkHg0U71100O10000O1000O001000N2N20O1O1O101N10OO200O001O001_IYOf0<Y3;mK_Oa0=a34mKA>?e31hKDa0<h3OeKH??BQO\\33dLg0KIa0k0o2gNcLe0LJ>n0c2dNRM11\\182d2eNoLN3\\17<^2d0`MB\\2>aMIY29eMJZ26dMNZ22eMOZ2n2M2O1M3RNTJK0h1Y6L1N102N1N2O2L3O2K5M3M2O2L20I6L5L23L3K6DoHGR78<O1M3N2O2N10001OO02O001N101NRU;0ljD300O1O10000O10000O1O1K5N2N2O1001O00001O001O001OSKBX2>gMDX2<iMCX2<hMDY2;hMEW2;hMHW27jMIU28jMIU28iMKU25kMLS27jMKP2:oMHQ28nMIQ28mMJR26nMKQ26nMKQ26mMLR24nMNP23oMMQ23iL\\ONc0X32ULXO45>c0V32VL]OM2f0c0TOROm3m0[L1a07e1kNbMh0<:JM?:g1U1fMcN?`0h1R2RNVNl1j1PNYNP2l32O0O1000mMnJV1g0dNj3]1oKgNS4X1gKmN[4S1\\KTOf4m0oJ[OT5g14L3M3M3M3M1O2N2N2N2N1O2K5K5J7I6J9D^i4'},
#    'area': 35858,
#    'bbox': [20, 0, 215, 255],
#    'predicted_iou': 0.9646507501602173,
#    'point_coords': [[206.0, 126.0]],
#    'stability_score': 0.9329656362533569,
#    'crop_box': [0, 0, 256, 256],
# ...

# %%
data.keys()
# Out:
# dict_keys(['annotations', 'semantic_mask'])

# %%
data['annotations']
# Out:
# [{'segmentation': {'size': [256, 256],
#    'counts': 'iV5112i70WH4e7J\\H;^7EcH>Z7CdH?[7BeH?Y7@gHc0W7]OjHb0V74000000O1OXOkHg0U71100O10000O1000O001000N2N20O1O1O101N10OO200O001O001_IYOf0<Y3;mK_Oa0=a34mKA>?e31hKDa0<h3OeKH??BQO\\33dLg0KIa0k0o2gNcLe0LJ>n0c2dNRM11\\182d2eNoLN3\\17<^2d0`MB\\2>aMIY29eMJZ26dMNZ22eMOZ2n2M2O1M3RNTJK0h1Y6L1N102N1N2O2L3O2K5M3M2O2L20I6L5L23L3K6DoHGR78<O1M3N2O2N10001OO02O001N101NRU;0ljD300O1O10000O10000O1O1K5N2N2O1001O00001O001O001OSKBX2>gMDX2<iMCX2<hMDY2;hMEW2;hMHW27jMIU28jMIU28iMKU25kMLS27jMKP2:oMHQ28nMIQ28mMJR26nMKQ26nMKQ26mMLR24nMNP23oMMQ23iL\\ONc0X32ULXO45>c0V32VL]OM2f0c0TOROm3m0[L1a07e1kNbMh0<:JM?:g1U1fMcN?`0h1R2RNVNl1j1PNYNP2l32O0O1000mMnJV1g0dNj3]1oKgNS4X1gKmN[4S1\\KTOf4m0oJ[OT5g14L3M3M3M3M1O2N2N2N2N1O2K5K5J7I6J9D^i4'},
#   'area': 35858,
#   'bbox': [20, 0, 215, 255],
#   'predicted_iou': 0.9646507501602173,
#   'point_coords': [[206.0, 126.0]],
#   'stability_score': 0.9329656362533569,
#   'crop_box': [0, 0, 256, 256],
#   'class_name': 'person',
# ...

# %%
len(data['annotations'])
# Out:
# 173

# %%
data['annotations'][0]['class_name']
# Out:
# 'person'
